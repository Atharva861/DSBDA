# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\Atharva\\Desktop\\final'

# %%
import pandas as pd

# %%
df = pd.read_csv('student_performance_data.csv')

# %%
df
# Out:
#      studentId  Age  gender  Ethnicity  ParentalEducation  StudyTimeWeekly  \
# 0         6062   17    Male          1                  1         7.980041
# 1         2915   19    Male          1                  1        11.652748
# 2         4827   15    Male          1                  3         4.018113
# 3         5975   19  Female          0                  3        18.795115
# 4         8311   16  Female          1                  4        11.134879
# ..         ...  ...     ...        ...                ...              ...
# 775       8148   19  Female          0                  3        11.310948
# 776       5791   15  Female          0                  3        13.410465
# 777       1313   18  Female          0                  2        16.076198
# 778       3760   19  Female          0                  4         5.380886
# 779       2877   16  Female          1                  1         4.676716
#
#      Absences  Tutoring  ParentalSupport  ExtraCurricular
# 0          14         0               14                0
# 1           6         0               11                1
# 2          29         1                1                0
# 3           9         1                7                0
# 4          13         1                1                1
# ..        ...       ...              ...              ...
# 775        29         0               13                1
# 776         8         1               13                1
# 777        15         0                3                1
# 778        20         1                1                0
# 779        20         0                5                1
#
# [780 rows x 10 columns]

# %%
df.shape
# Out:
# (780, 10)

# %%
df.head()
# Out:
#    studentId  Age  gender  Ethnicity  ParentalEducation  StudyTimeWeekly  \
# 0       6062   17    Male          1                  1         7.980041
# 1       2915   19    Male          1                  1        11.652748
# 2       4827   15    Male          1                  3         4.018113
# 3       5975   19  Female          0                  3        18.795115
# 4       8311   16  Female          1                  4        11.134879
#
#    Absences  Tutoring  ParentalSupport  ExtraCurricular
# 0        14         0               14                0
# 1         6         0               11                1
# 2        29         1                1                0
# 3         9         1                7                0
# 4        13         1                1                1

# %%
df.tail()
# Out:
#      studentId  Age  gender  Ethnicity  ParentalEducation  StudyTimeWeekly  \
# 775       8148   19  Female          0                  3        11.310948
# 776       5791   15  Female          0                  3        13.410465
# 777       1313   18  Female          0                  2        16.076198
# 778       3760   19  Female          0                  4         5.380886
# 779       2877   16  Female          1                  1         4.676716
#
#      Absences  Tutoring  ParentalSupport  ExtraCurricular
# 775        29         0               13                1
# 776         8         1               13                1
# 777        15         0                3                1
# 778        20         1                1                0
# 779        20         0                5                1

# %%
df.count()
# Out:
# studentId            780
# Age                  780
# gender               780
# Ethnicity            780
# ParentalEducation    780
# StudyTimeWeekly      780
# Absences             780
# Tutoring             780
# ParentalSupport      780
# ExtraCurricular      780
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 780 entries, 0 to 779
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   studentId          780 non-null    int64
#  1   Age                780 non-null    int64
#  2   gender             780 non-null    object
#  3   Ethnicity          780 non-null    int64
#  4   ParentalEducation  780 non-null    int64
#  5   StudyTimeWeekly    780 non-null    float64
#  6   Absences           780 non-null    int64
#  7   Tutoring           780 non-null    int64
#  8   ParentalSupport    780 non-null    int64
#  9   ExtraCurricular    780 non-null    int64
# dtypes: float64(1), int64(8), object(1)
# memory usage: 61.1+ KB

# %%
df.isnull()
# Out:
#      studentId    Age  gender  Ethnicity  ParentalEducation  StudyTimeWeekly  \
# 0        False  False   False      False              False            False
# 1        False  False   False      False              False            False
# 2        False  False   False      False              False            False
# 3        False  False   False      False              False            False
# 4        False  False   False      False              False            False
# ..         ...    ...     ...        ...                ...              ...
# 775      False  False   False      False              False            False
# 776      False  False   False      False              False            False
# 777      False  False   False      False              False            False
# 778      False  False   False      False              False            False
# 779      False  False   False      False              False            False
#
#      Absences  Tutoring  ParentalSupport  ExtraCurricular
# 0       False     False            False            False
# 1       False     False            False            False
# 2       False     False            False            False
# 3       False     False            False            False
# 4       False     False            False            False
# ..        ...       ...              ...              ...
# 775     False     False            False            False
# 776     False     False            False            False
# 777     False     False            False            False
# 778     False     False            False            False
# 779     False     False            False            False
#
# [780 rows x 10 columns]

# %%
df.isnull().sum()
# Out:
# studentId            0
# Age                  0
# gender               0
# Ethnicity            0
# ParentalEducation    0
# StudyTimeWeekly      0
# Absences             0
# Tutoring             0
# ParentalSupport      0
# ExtraCurricular      0
# dtype: int64

# %%
print(True+True)
# Out:
# 2

# %%
df.dropna()
# Out:
#      studentId  Age  gender  Ethnicity  ParentalEducation  StudyTimeWeekly  \
# 0         6062   17    Male          1                  1         7.980041
# 1         2915   19    Male          1                  1        11.652748
# 2         4827   15    Male          1                  3         4.018113
# 3         5975   19  Female          0                  3        18.795115
# 4         8311   16  Female          1                  4        11.134879
# ..         ...  ...     ...        ...                ...              ...
# 775       8148   19  Female          0                  3        11.310948
# 776       5791   15  Female          0                  3        13.410465
# 777       1313   18  Female          0                  2        16.076198
# 778       3760   19  Female          0                  4         5.380886
# 779       2877   16  Female          1                  1         4.676716
#
#      Absences  Tutoring  ParentalSupport  ExtraCurricular
# 0          14         0               14                0
# 1           6         0               11                1
# 2          29         1                1                0
# 3           9         1                7                0
# 4          13         1                1                1
# ..        ...       ...              ...              ...
# 775        29         0               13                1
# 776         8         1               13                1
# 777        15         0                3                1
# 778        20         1                1                0
# 779        20         0                5                1
#
# [780 rows x 10 columns]

# %%
df.fillna(0)
# Out:
#      studentId  Age  gender  Ethnicity  ParentalEducation  StudyTimeWeekly  \
# 0         6062   17    Male          1                  1         7.980041
# 1         2915   19    Male          1                  1        11.652748
# 2         4827   15    Male          1                  3         4.018113
# 3         5975   19  Female          0                  3        18.795115
# 4         8311   16  Female          1                  4        11.134879
# ..         ...  ...     ...        ...                ...              ...
# 775       8148   19  Female          0                  3        11.310948
# 776       5791   15  Female          0                  3        13.410465
# 777       1313   18  Female          0                  2        16.076198
# 778       3760   19  Female          0                  4         5.380886
# 779       2877   16  Female          1                  1         4.676716
#
#      Absences  Tutoring  ParentalSupport  ExtraCurricular
# 0          14         0               14                0
# 1           6         0               11                1
# 2          29         1                1                0
# 3           9         1                7                0
# 4          13         1                1                1
# ..        ...       ...              ...              ...
# 775        29         0               13                1
# 776         8         1               13                1
# 777        15         0                3                1
# 778        20         1                1                0
# 779        20         0                5                1
#
# [780 rows x 10 columns]

# %%
df['Age'].fillna('gender')
# Out:
# 0      17
# 1      19
# 2      15
# 3      19
# 4      16
#        ..
# 775    19
# 776    15
# 777    18
# 778    19
# 779    16
# Name: Age, Length: 780, dtype: int64

# %%
df['Absences'].fillna(df['Absences'].mean())
# Out:
# 0      14
# 1       6
# 2      29
# 3       9
# 4      13
#        ..
# 775    29
# 776     8
# 777    15
# 778    20
# 779    20
# Name: Absences, Length: 780, dtype: int64

# %%
df['Age'].fillna(df['Age'].median())
# Out:
# 0      17
# 1      19
# 2      15
# 3      19
# 4      16
#        ..
# 775    19
# 776    15
# 777    18
# 778    19
# 779    16
# Name: Age, Length: 780, dtype: int64

# %%
df['Ethnicity'].value_counts()
# Out:
# Ethnicity
# 0    391
# 1    389
# Name: count, dtype: int64

# %%
df['Ethnicity'].fillna(df['Ethnicity'].mode()[0])
# Out:
# 0      1
# 1      1
# 2      1
# 3      0
# 4      1
#       ..
# 775    0
# 776    0
# 777    0
# 778    0
# 779    1
# Name: Ethnicity, Length: 780, dtype: int64

# %%
df.fillna(method='backfill')
# Out:
# C:\Users\Atharva\AppData\Local\Temp\ipykernel_15776\340531938.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method='backfill')
#      studentId  Age  gender  Ethnicity  ParentalEducation  StudyTimeWeekly  \
# 0         6062   17    Male          1                  1         7.980041
# 1         2915   19    Male          1                  1        11.652748
# 2         4827   15    Male          1                  3         4.018113
# 3         5975   19  Female          0                  3        18.795115
# 4         8311   16  Female          1                  4        11.134879
# ..         ...  ...     ...        ...                ...              ...
# 775       8148   19  Female          0                  3        11.310948
# 776       5791   15  Female          0                  3        13.410465
# 777       1313   18  Female          0                  2        16.076198
# 778       3760   19  Female          0                  4         5.380886
# 779       2877   16  Female          1                  1         4.676716
#
#      Absences  Tutoring  ParentalSupport  ExtraCurricular
# 0          14         0               14                0
# 1           6         0               11                1
# 2          29         1                1                0
# 3           9         1                7                0
# 4          13         1                1                1
# ..        ...       ...              ...              ...
# 775        29         0               13                1
# 776         8         1               13                1
# 777        15         0                3                1
# 778        20         1                1                0
# 779        20         0                5                1
#
# [780 rows x 10 columns]

# %%
df.fillna(method='pad')
# Out:
# C:\Users\Atharva\AppData\Local\Temp\ipykernel_15776\196241153.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method='pad')
#      studentId  Age  gender  Ethnicity  ParentalEducation  StudyTimeWeekly  \
# 0         6062   17    Male          1                  1         7.980041
# 1         2915   19    Male          1                  1        11.652748
# 2         4827   15    Male          1                  3         4.018113
# 3         5975   19  Female          0                  3        18.795115
# 4         8311   16  Female          1                  4        11.134879
# ..         ...  ...     ...        ...                ...              ...
# 775       8148   19  Female          0                  3        11.310948
# 776       5791   15  Female          0                  3        13.410465
# 777       1313   18  Female          0                  2        16.076198
# 778       3760   19  Female          0                  4         5.380886
# 779       2877   16  Female          1                  1         4.676716
#
#      Absences  Tutoring  ParentalSupport  ExtraCurricular
# 0          14         0               14                0
# 1           6         0               11                1
# 2          29         1                1                0
# 3           9         1                7                0
# 4          13         1                1                1
# ..        ...       ...              ...              ...
# 775        29         0               13                1
# 776         8         1               13                1
# 777        15         0                3                1
# 778        20         1                1                0
# 779        20         0                5                1
#
# [780 rows x 10 columns]

# %%
df.describe()
# Out:
#          studentId         Age   Ethnicity  ParentalEducation  \
# count   780.000000  780.000000  780.000000         780.000000
# mean   5424.387179   17.530769    0.498718           2.912821
# std    2535.717134    1.693551    0.500319           1.429594
# min    1074.000000   15.000000    0.000000           1.000000
# 25%    3191.750000   16.000000    0.000000           2.000000
# 50%    5625.000000   18.000000    0.000000           3.000000
# 75%    7488.750000   19.000000    1.000000           4.000000
# max    9996.000000   20.000000    1.000000           5.000000
#
#        StudyTimeWeekly    Absences    Tutoring  ParentalSupport  \
# count       780.000000  780.000000  780.000000       780.000000
# mean         10.272124   15.069231    0.521795         8.148718
# std           5.791280    9.010211    0.499845         4.347361
# min           0.006677    0.000000    0.000000         1.000000
# 25%           5.238546    7.000000    0.000000         4.000000
# 50%          10.345276   15.000000    1.000000         8.000000
# 75%          15.311465   23.000000    1.000000        12.000000
# max          19.994770   30.000000    1.000000        15.000000
#
#        ExtraCurricular
# count       780.000000
# mean          0.514103
# std           0.500122
# min           0.000000
# 25%           0.000000
# 50%           1.000000
# 75%           1.000000
# max           1.000000

# %%
import numpy as np
x = np.array([12, 45, 7, 8, 25, 39, 50, 3, 16, 98])

# %%
np.mean(x)
# Out:
# np.float64(30.3)

# %%
np.median(x)
# Out:
# np.float64(20.5)

# %%
import matplotlib.pyplot as plt

# %%
plt.boxplot(x);

# %%
df.plot.box()
# Out:
# <Axes: >

# %%
df.loc[6,'studentId']
# Out:
# np.int64(8385)

# %%
df.loc[6,'studentId']=8385

# %%
df.plot.box()
# Out:
# <Axes: >

# %%
df.plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['Age'].plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
x= df[['Age','studentId']]

# %%
x.describe()
# Out:
#               Age    studentId
# count  780.000000   780.000000
# mean    17.530769  5424.387179
# std      1.693551  2535.717134
# min     15.000000  1074.000000
# 25%     16.000000  3191.750000
# 50%     18.000000  5625.000000
# 75%     19.000000  7488.750000
# max     20.000000  9996.000000

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
x_scaled = scaler.fit_transform(x)

# %%
pd.DataFrame(x_scaled).describe()
# Out:
#                 0           1
# count  780.000000  780.000000
# mean     0.506154    0.487602
# std      0.338710    0.284209
# min      0.000000    0.000000
# 25%      0.200000    0.237363
# 50%      0.600000    0.510087
# 75%      0.800000    0.718981
# max      1.000000    1.000000
