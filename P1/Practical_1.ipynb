# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('C:/Users/Atharva/Desktop/final/student_data.csv')
df
# Out:
#      Roll                Name Class  Marks  Age
# 0        1   Arush Srinivasan    TE     93   20
# 1        2       Charvi Bajaj    SE     86   22
# 2        3        Aryan Singh    TE     74   21
# 3        4  Samridhi Banerjee    TE     93   21
# 4        5         Komal Nair    TE     73   22
# ..     ...                ...   ...    ...  ...
# 145    146        Oorvi Kumar    TE     94   22
# 146    147    Palak Bhatnagar    BE     80   19
# 147    148      Garvit Murthy    SE     82   18
# 148    149      Upasana Mehta    TE     69   23
# 149    150  Charita Choudhary    TE     78   21
#
# [150 rows x 5 columns]

# %%
df.isnull()
# Out:
#      Roll    Name  Class  Marks    Age
# 0    False  False  False  False  False
# 1    False  False  False  False  False
# 2    False  False  False  False  False
# 3    False  False  False  False  False
# 4    False  False  False  False  False
# ..     ...    ...    ...    ...    ...
# 145  False  False  False  False  False
# 146  False  False  False  False  False
# 147  False  False  False  False  False
# 148  False  False  False  False  False
# 149  False  False  False  False  False
#
# [150 rows x 5 columns]

# %%
df.describe()
# Out:
#             Roll        Marks         Age
# count  150.000000  150.000000  150.000000
# mean    75.500000   79.853333   20.706667
# std     43.445368    8.794741    1.652928
# min      1.000000   65.000000   18.000000
# 25%     38.250000   73.000000   19.000000
# 50%     75.500000   79.000000   21.000000
# 75%    112.750000   87.000000   22.000000
# max    150.000000   95.000000   23.000000

# %%
size = df.size

# %%
shape = df.shape

# %%
df_ndim = df.ndim

# %%
series_ndim = df["Name"].ndim

# %%
print("Size = {}\nShape = {}\nShape[0] x Shape[1] = {}". 
       format(size, shape, shape[0]*shape[1]))
# Out:
# Size = 750
# Shape = (150, 5)
# Shape[0] x Shape[1] = 750

# %%
print("ndim of DataFrame = {}\nndim of series = {}".
       format (df_ndim, series_ndim))
# Out:
# ndim of DataFrame = 2
# ndim of series = 1

# %%
dataTypeSeries = df.dtypes

# %%
print("Data Type of Each column of Dataframe is:")
print(dataTypeSeries)
# Out:
# Data Type of Each column of Dataframe is:
# Roll      int64
# Name     object
# Class    object
# Marks     int64
# Age       int64
# dtype: object

# %%
dummies = pd.get_dummies(df.Class)

# %%
merged = pd.concat([df, dummies], axis = "columns")

# %%
merged.drop(["Class"], axis = "columns")
# Out:
#      Roll                Name  Marks  Age     BE     SE     TE
# 0        1   Arush Srinivasan     93   20  False  False   True
# 1        2       Charvi Bajaj     86   22  False   True  False
# 2        3        Aryan Singh     74   21  False  False   True
# 3        4  Samridhi Banerjee     93   21  False  False   True
# 4        5         Komal Nair     73   22  False  False   True
# ..     ...                ...    ...  ...    ...    ...    ...
# 145    146        Oorvi Kumar     94   22  False  False   True
# 146    147    Palak Bhatnagar     80   19   True  False  False
# 147    148      Garvit Murthy     82   18  False   True  False
# 148    149      Upasana Mehta     69   23  False  False   True
# 149    150  Charita Choudhary     78   21  False  False   True
#
# [150 rows x 7 columns]

# %%
print(merged)
# Out:
#      Roll                Name Class  Marks  Age     BE     SE     TE
# 0        1   Arush Srinivasan    TE     93   20  False  False   True
# 1        2       Charvi Bajaj    SE     86   22  False   True  False
# 2        3        Aryan Singh    TE     74   21  False  False   True
# 3        4  Samridhi Banerjee    TE     93   21  False  False   True
# 4        5         Komal Nair    TE     73   22  False  False   True
# ..     ...                ...   ...    ...  ...    ...    ...    ...
# 145    146        Oorvi Kumar    TE     94   22  False  False   True
# 146    147    Palak Bhatnagar    BE     80   19   True  False  False
# 147    148      Garvit Murthy    SE     82   18  False   True  False
# 148    149      Upasana Mehta    TE     69   23  False  False   True
# 149    150  Charita Choudhary    TE     78   21  False  False   True
#
# [150 rows x 8 columns]
